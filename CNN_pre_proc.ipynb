# %%
from PIL import Image
import os


img = Image.open(r"C:\Users\Welcome\Documents\MScAC\STA2453\Project\CodeRepo\STA2453-Zooplankton\data\PICS\COMBINED\20170411_FISHI_003_2mm_rep2_KG_data_2.tif")
img.size
# Out:
# (44, 63)

# %%
from PIL import Image
import os

# Set the input and output directories
input_directory = r"C:\Users\Welcome\Documents\MScAC\STA2453\Project\CodeRepo\STA2453-Zooplankton\data\combined_pics"
output_directory = r"C:\Users\Welcome\Documents\MScAC\STA2453\Project\CodeRepo\STA2453-Zooplankton\data\resized_combined_pics"

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# Define the target size
target_size = (50, 50)

# Loop through all images in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith(".tif"):
        # Open the image
        image_path = os.path.join(input_directory, filename)
        img = Image.open(image_path)

        # Resize the image
        img = img.resize(target_size, Image.LANCZOS)

        # Save the resized image to the output directory
        output_path = os.path.join(output_directory, filename)
        img.save(output_path)

print("All images resized successfully!")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[13], line 19
#      16 if filename.endswith(".tif"):
#      17     # Open the image
#      18     image_path = os.path.join(input_directory, filename)
# ---> 19     img = Image.open(image_path)
#      21     # Resize the image
#      22     img = img.resize(target_size, Image.LANCZOS)
#
# File c:\Users\Welcome\anaconda3\envs\sta2453\Lib\site-packages\PIL\Image.py:3532, in open(fp, mode, formats)
#    3530     warnings.warn(message)
#    3531 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3532 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file 'C:\\Users\\Welcome\\Documents\\MScAC\\STA2453\\Project\\CodeRepo\\STA2453-Zooplankton\\data\\combined_pics\\20180501_SIMC_017_2mm_rep1_KG_data_705.tif'

# %% [markdown]
# # Useless stuff below here

# %%
import torch
from torchvision.models import efficientnet_b0

# Load the model with pretrained weights from the original paper
model = efficientnet_b0(weights="IMAGENET1K_V1")  # Uses the ImageNet-pretrained weights

#model.eval()  # Set the model to evaluation mode
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to C:\Users\Welcome/.cache\torch\hub\checkpoints\efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 44.4MB/s]

# %%
print(model)
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#             (1): BatchNorm2d(64, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
# ...

# %%
from torchsummary import summary
summary(model, input_size=(3, 224, 224))  # Change input size if needed
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           1,728
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               SiLU-3         [-1, 64, 112, 112]               0
#             Conv2d-4         [-1, 64, 112, 112]             576
#        BatchNorm2d-5         [-1, 64, 112, 112]             128
#               SiLU-6         [-1, 64, 112, 112]               0
#  AdaptiveAvgPool2d-7             [-1, 64, 1, 1]               0
#             Conv2d-8             [-1, 16, 1, 1]           1,040
#               SiLU-9             [-1, 16, 1, 1]               0
#            Conv2d-10             [-1, 64, 1, 1]           1,088
#           Sigmoid-11             [-1, 64, 1, 1]               0
# SqueezeExcitation-12         [-1, 64, 112, 112]               0
#            Conv2d-13         [-1, 32, 112, 112]           2,048
# ...
